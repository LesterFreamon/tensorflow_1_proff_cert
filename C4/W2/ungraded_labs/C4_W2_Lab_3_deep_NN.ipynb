# %% [markdown]
# <a href="https://colab.research.google.com/github/https-deeplearning-ai/tensorflow-1-public/blob/main/C4/W2/ungraded_labs/C4_W2_Lab_3_deep_NN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ungraded Lab: Training a Deep Neural Network with Time Series Data
#
# In this lab, you will build upon the previous exercise and add more dense layers to your network. You will also look at a technique to tune the model's learning rate to make the weights converge faster. This is a useful tip so you can avoid guessing the learning rate before training.
#
# The initial steps will be identical to the previous lab so you can run the next cells until the `Build the Model` section. That's where the discussions begin.

# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Utilities

# %%
def plot_series(time, series, format="-", start=0, end=None):
    """
    Visualizes time series data

    Args:
      time (array of int) - contains the time steps
      series (array of int) - contains the measurements for each time step
      format - line style when plotting the graph
      label - tag for the line
      start - first time step to plot
      end - last time step to plot
    """

    # Setup dimensions of the graph figure
    plt.figure(figsize=(10, 6))
    
    if type(series) is tuple:

      for series_num in series:
        # Plot the time series data
        plt.plot(time[start:end], series_num[start:end], format)

    else:
      # Plot the time series data
      plt.plot(time[start:end], series[start:end], format)

    # Label the x-axis
    plt.xlabel("Time")

    # Label the y-axis
    plt.ylabel("Value")

    # Overlay a grid on the graph
    plt.grid(True)

    # Draw the graph on screen
    plt.show()

def trend(time, slope=0):
    """
    Generates synthetic data that follows a straight line given a slope value.

    Args:
      time (array of int) - contains the time steps
      slope (float) - determines the direction and steepness of the line

    Returns:
      series (array of float) - measurements that follow a straight line
    """

    # Compute the linear series given the slope
    series = slope * time

    return series

def seasonal_pattern(season_time):
    """
    Just an arbitrary pattern, you can change it if you wish
    
    Args:
      season_time (array of float) - contains the measurements per time step

    Returns:
      data_pattern (array of float) -  contains revised measurement values according 
                                  to the defined pattern
    """

    # Generate the values using an arbitrary pattern
    data_pattern = np.where(season_time < 0.4,
                    np.cos(season_time * 2 * np.pi),
                    1 / np.exp(3 * season_time))
    
    return data_pattern

def seasonality(time, period, amplitude=1, phase=0):
    """
    Repeats the same pattern at each period

    Args:
      time (array of int) - contains the time steps
      period (int) - number of time steps before the pattern repeats
      amplitude (int) - peak measured value in a period
      phase (int) - number of time steps to shift the measured values

    Returns:
      data_pattern (array of float) - seasonal data scaled by the defined amplitude
    """
    
    # Define the measured values per period
    season_time = ((time + phase) % period) / period

    # Generates the seasonal data scaled by the defined amplitude
    data_pattern = amplitude * seasonal_pattern(season_time)

    return data_pattern

def noise(time, noise_level=1, seed=None):
    """Generates a normally distributed noisy signal

    Args:
      time (array of int) - contains the time steps
      noise_level (float) - scaling factor for the generated signal
      seed (int) - number generator seed for repeatability

    Returns:
      noise (array of float) - the noisy signal
    """

    # Initialize the random number generator
    rnd = np.random.RandomState(seed)

    # Generate a random number for each time step and scale by the noise level
    noise = rnd.randn(len(time)) * noise_level
    
    return noise

# %% [markdown]
# ## Generate the Synthetic Data

# %%
# Parameters
time = np.arange(4 * 365 + 1, dtype="float32")
baseline = 10
amplitude = 40
slope = 0.05
noise_level = 5

# Create the series
series = baseline + trend(time, slope) + seasonality(time, period=365, amplitude=amplitude)

# Update with noise
series += noise(time, noise_level, seed=42)

# Plot the results
plot_series(time, series)

# %% [markdown]
# ## Split the Dataset

# %%
# Define the split time
split_time = 1000

# Get the train set 
time_train = time[:split_time]
x_train = series[:split_time]

# Get the validation set
time_valid = time[split_time:]
x_valid = series[split_time:]

# %% [markdown]
# ## Prepare Features and Labels

# %%
# Parameters
window_size = 20
batch_size = 32
shuffle_buffer_size = 1000

# %%
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
    """Generates dataset windows

    Args:
      series (array of float) - contains the values of the time series
      window_size (int) - the number of time steps to average
      batch_size (int) - the batch size
      shuffle_buffer(int) - buffer size to use for the shuffle method

    Returns:
      dataset (TF Dataset) - TF Dataset containing time windows
    """
  
    # Generate a TF Dataset from the series values
    dataset = tf.data.Dataset.from_tensor_slices(series)
    
    # Window the data but only take those with the specified size
    dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)
    
    # Flatten the windows by putting its elements in a single batch
    dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))

    # Create tuples with features and labels 
    dataset = dataset.map(lambda window: (window[:-1], window[-1]))

    # Shuffle the windows
    dataset = dataset.shuffle(shuffle_buffer)
    
    # Create batches of windows
    dataset = dataset.batch(batch_size).prefetch(1)
    
    return dataset

# %%
# Generate the dataset windows
dataset = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size)
# Out:
# 2023-02-13 17:06:22.054322: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-13 17:06:22.541904: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21571 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:65:00.0, compute capability: 8.6

# %% [markdown]
# ## Build the Model
#
# You will use three dense layers in this exercise as shown below. As expected, the number of trainable parameters will increase and the model summary shows that it is more than tenfold of the previous lab.

# %%
# Build the model
model_baseline = tf.keras.models.Sequential([
    tf.keras.layers.Dense(10, input_shape=[window_size], activation="relu"), 
    tf.keras.layers.Dense(10, activation="relu"), 
    tf.keras.layers.Dense(1)
])

# Print the model summary
model_baseline.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                210
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 331
# Trainable params: 331
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the Model
#
# You will then compile and train the model using the same settings as before. Observe how the loss is decreasing because you will revisit it later in this lab.

# %%
# Set the training parameters
model_baseline.compile(loss="mse", optimizer=tf.keras.optimizers.SGD(learning_rate=1e-6, momentum=0.9))

# %%
# Train the model
model_baseline.fit(dataset,epochs=100)
# Out:
# Epoch 1/100
#      19/Unknown - 1s 3ms/step - loss: 2216.0649
# 2023-02-13 17:06:27.172297: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 31/31 [==============================] - 2s 10ms/step - loss: 2226.2041
# Epoch 2/100
# 31/31 [==============================] - 0s 3ms/step - loss: 1046.7527
# Epoch 3/100
# 31/31 [==============================] - 0s 4ms/step - loss: 82.7786
# Epoch 4/100
# 31/31 [==============================] - 0s 4ms/step - loss: 62.1963
# Epoch 5/100
# 31/31 [==============================] - 0s 4ms/step - loss: 60.1815
# Epoch 6/100
# 31/31 [==============================] - 0s 4ms/step - loss: 60.2727
# Epoch 7/100
# 31/31 [==============================] - 0s 4ms/step - loss: 59.7401
# Epoch 8/100
# 31/31 [==============================] - 0s 4ms/step - loss: 58.8900
# Epoch 9/100
# 31/31 [==============================] - 0s 3ms/step - loss: 58.0498
# Epoch 10/100
# 31/31 [==============================] - 0s 3ms/step - loss: 57.5955
# Epoch 11/100
# 31/31 [==============================] - 0s 4ms/step - loss: 57.1795
# Epoch 12/100
# 31/31 [==============================] - 0s 4ms/step - loss: 56.9335
# Epoch 13/100
# 31/31 [==============================] - 0s 4ms/step - loss: 56.4496
# Epoch 14/100
# 31/31 [==============================] - 0s 4ms/step - loss: 55.9446
# Epoch 15/100
# 31/31 [==============================] - 0s 4ms/step - loss: 55.8402
# Epoch 16/100
# 31/31 [==============================] - 0s 3ms/step - loss: 55.1792
# Epoch 17/100
# 31/31 [==============================] - 0s 3ms/step - loss: 54.7907
# Epoch 18/100
# 31/31 [==============================] - 0s 3ms/step - loss: 55.9362
# Epoch 19/100
# 31/31 [==============================] - 0s 4ms/step - loss: 54.6921
# Epoch 20/100
# 31/31 [==============================] - 0s 4ms/step - loss: 54.1532
# Epoch 21/100
# 31/31 [==============================] - 0s 4ms/step - loss: 53.8311
# Epoch 22/100
# 31/31 [==============================] - 0s 4ms/step - loss: 53.5197
# Epoch 23/100
# 31/31 [==============================] - 0s 4ms/step - loss: 53.3236
# Epoch 24/100
# 31/31 [==============================] - 0s 4ms/step - loss: 53.3288
# Epoch 25/100
# 31/31 [==============================] - 0s 4ms/step - loss: 52.8927
# Epoch 26/100
# 31/31 [==============================] - 0s 4ms/step - loss: 52.8037
# Epoch 27/100
# 31/31 [==============================] - 0s 3ms/step - loss: 53.0552
# Epoch 28/100
# 31/31 [==============================] - 0s 4ms/step - loss: 52.3712
# Epoch 29/100
# 31/31 [==============================] - 0s 4ms/step - loss: 52.2133
# Epoch 30/100
# 31/31 [==============================] - 0s 4ms/step - loss: 52.2714
# Epoch 31/100
# 31/31 [==============================] - 0s 4ms/step - loss: 51.8544
# Epoch 32/100
# 31/31 [==============================] - 0s 4ms/step - loss: 51.1817
# Epoch 33/100
# 31/31 [==============================] - 0s 4ms/step - loss: 52.3871
# Epoch 34/100
# 31/31 [==============================] - 0s 4ms/step - loss: 51.4313
# Epoch 35/100
# 31/31 [==============================] - 0s 4ms/step - loss: 51.2752
# Epoch 36/100
# 31/31 [==============================] - 0s 3ms/step - loss: 51.5621
# Epoch 37/100
# 31/31 [==============================] - 0s 4ms/step - loss: 51.1440
# Epoch 38/100
# 31/31 [==============================] - 0s 4ms/step - loss: 50.8145
# Epoch 39/100
# 31/31 [==============================] - 0s 4ms/step - loss: 51.1180
# Epoch 40/100
# 31/31 [==============================] - 0s 4ms/step - loss: 50.4184
# Epoch 41/100
# 31/31 [==============================] - 0s 4ms/step - loss: 50.6567
# Epoch 42/100
# 31/31 [==============================] - 0s 3ms/step - loss: 50.4533
# Epoch 43/100
# 31/31 [==============================] - 0s 3ms/step - loss: 50.2393
# Epoch 44/100
# 31/31 [==============================] - 0s 4ms/step - loss: 50.4449
# Epoch 45/100
# 31/31 [==============================] - 0s 3ms/step - loss: 50.0708
# Epoch 46/100
# 31/31 [==============================] - 0s 2ms/step - loss: 49.7848
# Epoch 47/100
# 31/31 [==============================] - 0s 3ms/step - loss: 50.1247
# Epoch 48/100
# 31/31 [==============================] - 0s 4ms/step - loss: 49.7507
# Epoch 49/100
# 31/31 [==============================] - 0s 4ms/step - loss: 49.6907
# Epoch 50/100
# 31/31 [==============================] - 0s 4ms/step - loss: 49.8132
# Epoch 51/100
# 31/31 [==============================] - 0s 4ms/step - loss: 49.2425
# Epoch 52/100
# 31/31 [==============================] - 0s 4ms/step - loss: 50.0575
# Epoch 53/100
# 31/31 [==============================] - 0s 4ms/step - loss: 49.4961
# Epoch 54/100
# 31/31 [==============================] - 0s 4ms/step - loss: 49.3046
# Epoch 55/100
# 31/31 [==============================] - 0s 3ms/step - loss: 49.0846
# Epoch 56/100
# 31/31 [==============================] - 0s 2ms/step - loss: 48.9843
# Epoch 57/100
# 31/31 [==============================] - 0s 3ms/step - loss: 49.0142
# Epoch 58/100
# 31/31 [==============================] - 0s 3ms/step - loss: 48.8006
# Epoch 59/100
# 31/31 [==============================] - 0s 4ms/step - loss: 48.9107
# Epoch 60/100
# 31/31 [==============================] - 0s 4ms/step - loss: 48.6904
# Epoch 61/100
# 31/31 [==============================] - 0s 4ms/step - loss: 48.6648
# Epoch 62/100
# 31/31 [==============================] - 0s 4ms/step - loss: 49.1413
# Epoch 63/100
# 31/31 [==============================] - 0s 4ms/step - loss: 48.2841
# Epoch 64/100
# 31/31 [==============================] - 0s 4ms/step - loss: 48.4049
# Epoch 65/100
# 31/31 [==============================] - 0s 4ms/step - loss: 48.2304
# Epoch 66/100
# 31/31 [==============================] - 0s 4ms/step - loss: 48.1624
# Epoch 67/100
# 31/31 [==============================] - 0s 3ms/step - loss: 48.0836
# Epoch 68/100
# 31/31 [==============================] - 0s 4ms/step - loss: 48.1318
# Epoch 69/100
# 31/31 [==============================] - 0s 4ms/step - loss: 47.9705
# Epoch 70/100
# 31/31 [==============================] - 0s 3ms/step - loss: 47.9898
# Epoch 71/100
# 31/31 [==============================] - 0s 4ms/step - loss: 48.4419
# Epoch 72/100
# 31/31 [==============================] - 0s 4ms/step - loss: 48.2348
# Epoch 73/100
# 31/31 [==============================] - 0s 4ms/step - loss: 47.6830
# Epoch 74/100
# 31/31 [==============================] - 0s 4ms/step - loss: 47.6196
# Epoch 75/100
# 31/31 [==============================] - 0s 4ms/step - loss: 47.6001
# Epoch 76/100
# 31/31 [==============================] - 0s 4ms/step - loss: 47.9374
# Epoch 77/100
# 31/31 [==============================] - 0s 3ms/step - loss: 47.5814
# Epoch 78/100
# 31/31 [==============================] - 0s 4ms/step - loss: 47.3782
# Epoch 79/100
# 31/31 [==============================] - 0s 4ms/step - loss: 47.4074
# Epoch 80/100
# 31/31 [==============================] - 0s 4ms/step - loss: 47.1599
# Epoch 81/100
# 31/31 [==============================] - 0s 4ms/step - loss: 47.1272
# Epoch 82/100
# 31/31 [==============================] - 0s 4ms/step - loss: 47.1951
# Epoch 83/100
# 31/31 [==============================] - 0s 4ms/step - loss: 47.2334
# Epoch 84/100
# 31/31 [==============================] - 0s 4ms/step - loss: 47.0575
# Epoch 85/100
# 31/31 [==============================] - 0s 4ms/step - loss: 47.3815
# Epoch 86/100
# 31/31 [==============================] - 0s 4ms/step - loss: 47.1635
# Epoch 87/100
# 31/31 [==============================] - 0s 3ms/step - loss: 46.7908
# Epoch 88/100
# 31/31 [==============================] - 0s 4ms/step - loss: 46.8839
# Epoch 89/100
# 31/31 [==============================] - 0s 4ms/step - loss: 46.9118
# Epoch 90/100
# 31/31 [==============================] - 0s 4ms/step - loss: 46.8627
# Epoch 91/100
# 31/31 [==============================] - 0s 4ms/step - loss: 46.9838
# Epoch 92/100
# 31/31 [==============================] - 0s 4ms/step - loss: 46.8302
# Epoch 93/100
# 31/31 [==============================] - 0s 4ms/step - loss: 46.6654
# Epoch 94/100
# 31/31 [==============================] - 0s 4ms/step - loss: 46.4979
# Epoch 95/100
# 31/31 [==============================] - 0s 2ms/step - loss: 46.4576
# Epoch 96/100
# 31/31 [==============================] - 0s 4ms/step - loss: 46.4191
# Epoch 97/100
# 31/31 [==============================] - 0s 4ms/step - loss: 46.2100
# Epoch 98/100
# 31/31 [==============================] - 0s 4ms/step - loss: 46.2784
# Epoch 99/100
# 31/31 [==============================] - 0s 4ms/step - loss: 46.3503
# Epoch 100/100
# 31/31 [==============================] - 0s 4ms/step - loss: 46.3601

# %% [markdown]
# You can then get some predictions and visualize it as before. Since the network is deeper, the predictions might go slower so you may want to minimize unnecessary computations.
#
# In the previous lab, you might remember the model generating predictions using the entire `series` data. That resulted in 1,441 points in the `forecast` list then you sliced the 461 points that aligns with the validation set using `forecast = forecast[split_time - window_size:]`.
#
# You can make this process faster by just generating 461 points right from the start. That way, you don't waste time predicting points that will just be thrown away later. The code below will do just that. It will just get the points needed from the original `series` before calling the `predict()` method. With that, all predictions will align with the validation set already and the for-loop will run for only 461 times instead of 1,441.
#
# In the next lab, you'll see an even faster way to generate these predictions.

# %%
# Initialize a list
forecast = []

# Reduce the original series
forecast_series = series[split_time - window_size:]

# Use the model to predict data points per window size
for time in range(len(forecast_series) - window_size):
  forecast.append(model_baseline.predict(forecast_series[time:time + window_size][np.newaxis]))

# Convert to a numpy array and drop single dimensional axes
results = np.array(forecast).squeeze()

# Plot the results
plot_series(time_valid, (x_valid, results))

# %% [markdown]
# You can then get the MSE and MAE for reference.

# %%
# Compute the metrics
print(tf.keras.metrics.mean_squared_error(x_valid, results).numpy())
print(tf.keras.metrics.mean_absolute_error(x_valid, results).numpy())
# Out:
# 52.48455
# 5.3506994

# %% [markdown]
# ## Tune the learning rate
#
# You saw that the training went well with the initial learning rate that you chose (i.e. `1e-6`). However, you're not yet sure if it is the best setting for this particular model. It might seem inconsequential in this simple model but when you have more complex ones, spending some time to tune the learning rate can lead to better training results. You will see how to do that in this section.
#
# First, you will build the same model architecture you just used.

# %%
# Build the Model
model_tune = tf.keras.models.Sequential([
    tf.keras.layers.Dense(10, input_shape=[window_size], activation="relu"), 
    tf.keras.layers.Dense(10, activation="relu"), 
    tf.keras.layers.Dense(1)
])

# %% [markdown]
# Next, you will declare a [learning rate scheduler](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/LearningRateScheduler) callback. This will allow you to dynamically set the learning rate based on the epoch number during training. As shown below, you will pass a lambda function to declare the value of the learning rate. It will start at `1e-8` at epoch 0 and is scaled by `10**(epoch / 20)` as the training goes on.

# %%
# Set the learning rate scheduler
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-8 * 10**(epoch / 20))

# %% [markdown]
# You will then compile the model. Just to note a subtle difference with the lecture video, you don't have to set the `learning_rate` argument of the optimizer here before compiling. You can just leave the default (i.e. [`0.01` for SGD](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/SGD#args)) and allow the learning rate scheduler to set it dynamically.

# %%
# Initialize the optimizer
optimizer = tf.keras.optimizers.SGD(momentum=0.9)

# Set the training parameters
model_tune.compile(loss="mse", optimizer=optimizer)

# %% [markdown]
# You will pass in the `lr_schedule` callback in the `callbacks` parameter of the [`fit()`](https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit) method. As you run the training below, you will see the learning rate at a particular epoch denoted by `lr` in the console output. Notice that it is increasing as expected based on the lambda function you used.

# %%
# Train the model
history = model_tune.fit(dataset, epochs=100, callbacks=[lr_schedule])
# Out:
# Epoch 1/100
# 31/31 [==============================] - 1s 5ms/step - loss: 1411.1129 - lr: 1.0000e-08
# Epoch 2/100
# 31/31 [==============================] - 0s 4ms/step - loss: 1334.1124 - lr: 1.1220e-08
# Epoch 3/100
# 31/31 [==============================] - 0s 4ms/step - loss: 1237.4578 - lr: 1.2589e-08
# Epoch 4/100
# 31/31 [==============================] - 0s 4ms/step - loss: 1125.7509 - lr: 1.4125e-08
# Epoch 5/100
# 31/31 [==============================] - 0s 4ms/step - loss: 997.9204 - lr: 1.5849e-08
# Epoch 6/100
# 31/31 [==============================] - 0s 4ms/step - loss: 855.8503 - lr: 1.7783e-08
# Epoch 7/100
# 31/31 [==============================] - 0s 3ms/step - loss: 704.6459 - lr: 1.9953e-08
# Epoch 8/100
# 31/31 [==============================] - 0s 4ms/step - loss: 552.5249 - lr: 2.2387e-08
# Epoch 9/100
# 31/31 [==============================] - 0s 4ms/step - loss: 410.3315 - lr: 2.5119e-08
# Epoch 10/100
# 31/31 [==============================] - 0s 4ms/step - loss: 291.2820 - lr: 2.8184e-08
# Epoch 11/100
# 31/31 [==============================] - 0s 4ms/step - loss: 204.7110 - lr: 3.1623e-08
# Epoch 12/100
# 31/31 [==============================] - 0s 4ms/step - loss: 152.5377 - lr: 3.5481e-08
# Epoch 13/100
# 31/31 [==============================] - 0s 4ms/step - loss: 126.6302 - lr: 3.9811e-08
# Epoch 14/100
# 31/31 [==============================] - 0s 3ms/step - loss: 116.8605 - lr: 4.4668e-08
# Epoch 15/100
# 31/31 [==============================] - 0s 3ms/step - loss: 113.4929 - lr: 5.0119e-08
# Epoch 16/100
# 31/31 [==============================] - 0s 3ms/step - loss: 112.3566 - lr: 5.6234e-08
# Epoch 17/100
# 31/31 [==============================] - 0s 3ms/step - loss: 111.4707 - lr: 6.3096e-08
# Epoch 18/100
# 31/31 [==============================] - 0s 4ms/step - loss: 110.6880 - lr: 7.0795e-08
# Epoch 19/100
# 31/31 [==============================] - 0s 4ms/step - loss: 109.6845 - lr: 7.9433e-08
# Epoch 20/100
# 31/31 [==============================] - 0s 4ms/step - loss: 108.7148 - lr: 8.9125e-08
# Epoch 21/100
# 31/31 [==============================] - 0s 4ms/step - loss: 107.6916 - lr: 1.0000e-07
# Epoch 22/100
# 31/31 [==============================] - 0s 4ms/step - loss: 106.7140 - lr: 1.1220e-07
# Epoch 23/100
# 31/31 [==============================] - 0s 4ms/step - loss: 105.3665 - lr: 1.2589e-07
# Epoch 24/100
# 31/31 [==============================] - 0s 4ms/step - loss: 104.2007 - lr: 1.4125e-07
# Epoch 25/100
# 31/31 [==============================] - 0s 3ms/step - loss: 103.0440 - lr: 1.5849e-07
# Epoch 26/100
# 31/31 [==============================] - 0s 3ms/step - loss: 101.8771 - lr: 1.7783e-07
# Epoch 27/100
# 31/31 [==============================] - 0s 4ms/step - loss: 100.6617 - lr: 1.9953e-07
# Epoch 28/100
# 31/31 [==============================] - 0s 4ms/step - loss: 99.2871 - lr: 2.2387e-07
# Epoch 29/100
# 31/31 [==============================] - 0s 4ms/step - loss: 97.8531 - lr: 2.5119e-07
# Epoch 30/100
# 31/31 [==============================] - 0s 4ms/step - loss: 96.2761 - lr: 2.8184e-07
# Epoch 31/100
# 31/31 [==============================] - 0s 4ms/step - loss: 94.5595 - lr: 3.1623e-07
# Epoch 32/100
# 31/31 [==============================] - 0s 4ms/step - loss: 93.0286 - lr: 3.5481e-07
# Epoch 33/100
# 31/31 [==============================] - 0s 3ms/step - loss: 91.1151 - lr: 3.9811e-07
# Epoch 34/100
# 31/31 [==============================] - 0s 4ms/step - loss: 88.9919 - lr: 4.4668e-07
# Epoch 35/100
# 31/31 [==============================] - 0s 3ms/step - loss: 86.7664 - lr: 5.0119e-07
# Epoch 36/100
# 31/31 [==============================] - 0s 4ms/step - loss: 83.9702 - lr: 5.6234e-07
# Epoch 37/100
# 31/31 [==============================] - 0s 4ms/step - loss: 80.9699 - lr: 6.3096e-07
# Epoch 38/100
# 31/31 [==============================] - 0s 4ms/step - loss: 77.1475 - lr: 7.0795e-07
# Epoch 39/100
# 31/31 [==============================] - 0s 4ms/step - loss: 74.7791 - lr: 7.9433e-07
# Epoch 40/100
# 31/31 [==============================] - 0s 4ms/step - loss: 72.5623 - lr: 8.9125e-07
# Epoch 41/100
# 31/31 [==============================] - 0s 4ms/step - loss: 69.6669 - lr: 1.0000e-06
# Epoch 42/100
# 31/31 [==============================] - 0s 4ms/step - loss: 67.3163 - lr: 1.1220e-06
# Epoch 43/100
# 31/31 [==============================] - 0s 4ms/step - loss: 64.9165 - lr: 1.2589e-06
# Epoch 44/100
# 31/31 [==============================] - 0s 4ms/step - loss: 62.3079 - lr: 1.4125e-06
# Epoch 45/100
# 31/31 [==============================] - 0s 4ms/step - loss: 59.6641 - lr: 1.5849e-06
# Epoch 46/100
# 31/31 [==============================] - 0s 4ms/step - loss: 58.4939 - lr: 1.7783e-06
# Epoch 47/100
# 31/31 [==============================] - 0s 4ms/step - loss: 56.5129 - lr: 1.9953e-06
# Epoch 48/100
# 31/31 [==============================] - 0s 4ms/step - loss: 54.7483 - lr: 2.2387e-06
# Epoch 49/100
# 31/31 [==============================] - 0s 4ms/step - loss: 53.6420 - lr: 2.5119e-06
# Epoch 50/100
# 31/31 [==============================] - 0s 4ms/step - loss: 54.4174 - lr: 2.8184e-06
# Epoch 51/100
# 31/31 [==============================] - 0s 4ms/step - loss: 54.9275 - lr: 3.1623e-06
# Epoch 52/100
# 31/31 [==============================] - 0s 4ms/step - loss: 51.5540 - lr: 3.5481e-06
# Epoch 53/100
# 31/31 [==============================] - 0s 4ms/step - loss: 52.4735 - lr: 3.9811e-06
# Epoch 54/100
# 31/31 [==============================] - 0s 4ms/step - loss: 50.6609 - lr: 4.4668e-06
# Epoch 55/100
# 31/31 [==============================] - 0s 4ms/step - loss: 55.8364 - lr: 5.0119e-06
# Epoch 56/100
# 31/31 [==============================] - 0s 2ms/step - loss: 52.0939 - lr: 5.6234e-06
# Epoch 57/100
# 31/31 [==============================] - 0s 4ms/step - loss: 49.8579 - lr: 6.3096e-06
# Epoch 58/100
# 31/31 [==============================] - 0s 4ms/step - loss: 50.9178 - lr: 7.0795e-06
# Epoch 59/100
# 31/31 [==============================] - 0s 4ms/step - loss: 53.3956 - lr: 7.9433e-06
# Epoch 60/100
# 31/31 [==============================] - 0s 4ms/step - loss: 46.4378 - lr: 8.9125e-06
# Epoch 61/100
# 31/31 [==============================] - 0s 4ms/step - loss: 47.1382 - lr: 1.0000e-05
# Epoch 62/100
# 31/31 [==============================] - 0s 4ms/step - loss: 47.0542 - lr: 1.1220e-05
# Epoch 63/100
# 31/31 [==============================] - 0s 4ms/step - loss: 48.5717 - lr: 1.2589e-05
# Epoch 64/100
# 31/31 [==============================] - 0s 4ms/step - loss: 45.2776 - lr: 1.4125e-05
# Epoch 65/100
# 31/31 [==============================] - 0s 4ms/step - loss: 45.1632 - lr: 1.5849e-05
# Epoch 66/100
# 31/31 [==============================] - 0s 4ms/step - loss: 46.2305 - lr: 1.7783e-05
# Epoch 67/100
# 31/31 [==============================] - 0s 4ms/step - loss: 61.9579 - lr: 1.9953e-05
# Epoch 68/100
# 31/31 [==============================] - 0s 4ms/step - loss: 49.5920 - lr: 2.2387e-05
# Epoch 69/100
# 31/31 [==============================] - 0s 4ms/step - loss: 49.1924 - lr: 2.5119e-05
# Epoch 70/100
# 31/31 [==============================] - 0s 4ms/step - loss: 70.7750 - lr: 2.8184e-05
# Epoch 71/100
# 31/31 [==============================] - 0s 4ms/step - loss: 43.5207 - lr: 3.1623e-05
# Epoch 72/100
# 31/31 [==============================] - 0s 4ms/step - loss: 45.5290 - lr: 3.5481e-05
# Epoch 73/100
# 31/31 [==============================] - 0s 4ms/step - loss: 43.6561 - lr: 3.9811e-05
# Epoch 74/100
# 31/31 [==============================] - 0s 4ms/step - loss: 53.3660 - lr: 4.4668e-05
# Epoch 75/100
# 31/31 [==============================] - 0s 4ms/step - loss: 67.1690 - lr: 5.0119e-05
# Epoch 76/100
# 31/31 [==============================] - 0s 4ms/step - loss: 62.2950 - lr: 5.6234e-05
# Epoch 77/100
# 31/31 [==============================] - 0s 4ms/step - loss: 1310.8804 - lr: 6.3096e-05
# Epoch 78/100
# 31/31 [==============================] - 0s 4ms/step - loss: 40790.9375 - lr: 7.0795e-05
# Epoch 79/100
# 31/31 [==============================] - 0s 4ms/step - loss: 2002.5251 - lr: 7.9433e-05
# Epoch 80/100
# 31/31 [==============================] - 0s 4ms/step - loss: 1848.7937 - lr: 8.9125e-05
# Epoch 81/100
# 31/31 [==============================] - 0s 4ms/step - loss: 1696.8645 - lr: 1.0000e-04
# Epoch 82/100
# 31/31 [==============================] - 0s 4ms/step - loss: 1544.6029 - lr: 1.1220e-04
# Epoch 83/100
# 31/31 [==============================] - 0s 4ms/step - loss: 1396.1787 - lr: 1.2589e-04
# Epoch 84/100
# 31/31 [==============================] - 0s 4ms/step - loss: 1252.5404 - lr: 1.4125e-04
# Epoch 85/100
# 31/31 [==============================] - 0s 4ms/step - loss: 1116.7391 - lr: 1.5849e-04
# Epoch 86/100
# 31/31 [==============================] - 0s 4ms/step - loss: 991.4495 - lr: 1.7783e-04
# Epoch 87/100
# 31/31 [==============================] - 0s 4ms/step - loss: 877.0474 - lr: 1.9953e-04
# Epoch 88/100
# 31/31 [==============================] - 0s 4ms/step - loss: 776.6979 - lr: 2.2387e-04
# Epoch 89/100
# 31/31 [==============================] - 0s 4ms/step - loss: 691.0068 - lr: 2.5119e-04
# Epoch 90/100
# 31/31 [==============================] - 0s 4ms/step - loss: 620.2239 - lr: 2.8184e-04
# Epoch 91/100
# 31/31 [==============================] - 0s 3ms/step - loss: 563.4866 - lr: 3.1623e-04
# Epoch 92/100
# 31/31 [==============================] - 0s 3ms/step - loss: 522.0175 - lr: 3.5481e-04
# Epoch 93/100
# 31/31 [==============================] - 0s 3ms/step - loss: 490.7748 - lr: 3.9811e-04
# Epoch 94/100
# 31/31 [==============================] - 0s 4ms/step - loss: 470.7573 - lr: 4.4668e-04
# Epoch 95/100
# 31/31 [==============================] - 0s 4ms/step - loss: 457.4200 - lr: 5.0119e-04
# Epoch 96/100
# 31/31 [==============================] - 0s 4ms/step - loss: 450.0808 - lr: 5.6234e-04
# Epoch 97/100
# 31/31 [==============================] - 0s 4ms/step - loss: 445.5846 - lr: 6.3096e-04
# Epoch 98/100
# 31/31 [==============================] - 0s 4ms/step - loss: 443.8248 - lr: 7.0795e-04
# Epoch 99/100
# 31/31 [==============================] - 0s 4ms/step - loss: 444.1493 - lr: 7.9433e-04
# Epoch 100/100
# 31/31 [==============================] - 0s 4ms/step - loss: 451.2579 - lr: 8.9125e-04

# %% [markdown]
# Next step is to plot the results of the training. You will visualize the loss at each value of the learning rate.

# %%
# Define the learning rate array
lrs = 1e-8 * (10 ** (np.arange(100) / 20))

# Set the figure size
plt.figure(figsize=(10, 6))

# Set the grid
plt.grid(True)

# Plot the loss in log scale
plt.semilogx(lrs, history.history["loss"])

# Increase the tickmarks size
plt.tick_params('both', length=10, width=1, which='both')

# Set the plot boundaries
plt.axis([1e-8, 1e-3, 0, 300])
# Out:
# (1e-08, 0.001, 0.0, 300.0)

# %% [markdown]
# The generated graph above shows the values of the range of learning rates that leads to lower losses (i.e. sloping downward) and also which ones cause the training to become unstable (i.e. jagged edges and pointing upwards). In general, you will want to pick a point in a downward slope. That means the network is still learning at that point and is stable. Choosing close to the minimum point of the graph will make the training converge to that loss value quicker, as will be shown in the next cells.
#
# First, you will initialize the same model architecture again.

# %%
# Build the model
model_tune = tf.keras.models.Sequential([
  tf.keras.layers.Dense(10, activation="relu", input_shape=[window_size]),
  tf.keras.layers.Dense(10, activation="relu"),
  tf.keras.layers.Dense(1)
])

# %% [markdown]
# You will then set the optimizer with a learning rate close to the minimum. It is set to `4e-6` initially but feel free to change based on your results.

# %%
# Set the optimizer with the tuned learning rate
optimizer = tf.keras.optimizers.SGD(learning_rate=4e-6, momentum=0.9)

# %% [markdown]
# You can then compile and train the model as before. Observe the loss values and compare it to the output of the baseline model you had before. Most likely, you will have met the final loss value of the `model_baseline` within the first 50 epochs of training this `model_tune`. You will also likely have a lower loss after all 100 epochs are done.

# %%
# Set the training parameters
model_tune.compile(loss="mse", optimizer=optimizer)

# Train the model
history = model_tune.fit(dataset, epochs=400)
# Out:
# Epoch 1/400
# 31/31 [==============================] - 0s 4ms/step - loss: 39.9128
# Epoch 2/400
# 31/31 [==============================] - 0s 4ms/step - loss: 39.2068
# Epoch 3/400
# 31/31 [==============================] - 0s 4ms/step - loss: 39.3286
# Epoch 4/400
# 31/31 [==============================] - 0s 4ms/step - loss: 39.4409
# Epoch 5/400
# 31/31 [==============================] - 0s 4ms/step - loss: 39.2346
# Epoch 6/400
# 31/31 [==============================] - 0s 4ms/step - loss: 39.0997
# Epoch 7/400
# 31/31 [==============================] - 0s 4ms/step - loss: 39.0399
# Epoch 8/400
# 31/31 [==============================] - 0s 4ms/step - loss: 39.3188
# Epoch 9/400
# 31/31 [==============================] - 0s 4ms/step - loss: 40.8585
# Epoch 10/400
# 31/31 [==============================] - 0s 4ms/step - loss: 41.2516
# Epoch 11/400
# 31/31 [==============================] - 0s 4ms/step - loss: 39.7780
# Epoch 12/400
# 31/31 [==============================] - 0s 4ms/step - loss: 38.7218
# Epoch 13/400
# 31/31 [==============================] - 0s 4ms/step - loss: 38.8879
# Epoch 14/400
# 31/31 [==============================] - 0s 4ms/step - loss: 39.8432
# Epoch 15/400
# 31/31 [==============================] - 0s 2ms/step - loss: 39.8389
# Epoch 16/400
# 31/31 [==============================] - 0s 3ms/step - loss: 38.6847
# Epoch 17/400
# 31/31 [==============================] - 0s 4ms/step - loss: 38.9028
# Epoch 18/400
# 31/31 [==============================] - 0s 4ms/step - loss: 39.0625
# Epoch 19/400
# 31/31 [==============================] - 0s 4ms/step - loss: 38.7703
# Epoch 20/400
# 31/31 [==============================] - 0s 4ms/step - loss: 38.4472
# Epoch 21/400
# 31/31 [==============================] - 0s 4ms/step - loss: 38.4988
# Epoch 22/400
# 31/31 [==============================] - 0s 4ms/step - loss: 38.2993
# Epoch 23/400
# 31/31 [==============================] - 0s 4ms/step - loss: 38.9571
# Epoch 24/400
# 31/31 [==============================] - 0s 4ms/step - loss: 39.7642
# Epoch 25/400
# 31/31 [==============================] - 0s 4ms/step - loss: 39.4879
# Epoch 26/400
# 31/31 [==============================] - 0s 4ms/step - loss: 38.2123
# Epoch 27/400
# 31/31 [==============================] - 0s 4ms/step - loss: 40.5103
# Epoch 28/400
# 31/31 [==============================] - 0s 3ms/step - loss: 39.7216
# Epoch 29/400
# 31/31 [==============================] - 0s 4ms/step - loss: 38.5089
# Epoch 30/400
# 31/31 [==============================] - 0s 4ms/step - loss: 39.0066
# Epoch 31/400
# 31/31 [==============================] - 0s 4ms/step - loss: 38.3981
# Epoch 32/400
# 31/31 [==============================] - 0s 4ms/step - loss: 38.1474
# Epoch 33/400
# 31/31 [==============================] - 0s 3ms/step - loss: 38.1147
# Epoch 34/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.9942
# Epoch 35/400
# 31/31 [==============================] - 0s 4ms/step - loss: 38.2017
# Epoch 36/400
# 31/31 [==============================] - 0s 3ms/step - loss: 38.1483
# Epoch 37/400
# 31/31 [==============================] - 0s 4ms/step - loss: 39.6616
# Epoch 38/400
# 31/31 [==============================] - 0s 4ms/step - loss: 38.6285
# Epoch 39/400
# 31/31 [==============================] - 0s 3ms/step - loss: 38.2130
# Epoch 40/400
# 31/31 [==============================] - 0s 3ms/step - loss: 37.8427
# Epoch 41/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.9138
# Epoch 42/400
# 31/31 [==============================] - 0s 4ms/step - loss: 38.1577
# Epoch 43/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.8586
# Epoch 44/400
# 31/31 [==============================] - 0s 4ms/step - loss: 38.4914
# Epoch 45/400
# 31/31 [==============================] - 0s 4ms/step - loss: 38.2765
# Epoch 46/400
# 31/31 [==============================] - 0s 4ms/step - loss: 38.5606
# Epoch 47/400
# 31/31 [==============================] - 0s 4ms/step - loss: 38.1039
# Epoch 48/400
# 31/31 [==============================] - 0s 4ms/step - loss: 38.1392
# Epoch 49/400
# 31/31 [==============================] - 0s 4ms/step - loss: 38.4414
# Epoch 50/400
# 31/31 [==============================] - 0s 4ms/step - loss: 39.0202
# Epoch 51/400
# 31/31 [==============================] - 0s 4ms/step - loss: 38.2342
# Epoch 52/400
# 31/31 [==============================] - 0s 4ms/step - loss: 39.7188
# Epoch 53/400
# 31/31 [==============================] - 0s 3ms/step - loss: 38.4002
# Epoch 54/400
# 31/31 [==============================] - 0s 3ms/step - loss: 37.4585
# Epoch 55/400
# 31/31 [==============================] - 0s 3ms/step - loss: 37.7268
# Epoch 56/400
# 31/31 [==============================] - 0s 3ms/step - loss: 37.9622
# Epoch 57/400
# 31/31 [==============================] - 0s 4ms/step - loss: 38.3572
# Epoch 58/400
# 31/31 [==============================] - 0s 3ms/step - loss: 37.7725
# Epoch 59/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.8372
# Epoch 60/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.4706
# Epoch 61/400
# 31/31 [==============================] - 0s 3ms/step - loss: 37.5083
# Epoch 62/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.3967
# Epoch 63/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.4618
# Epoch 64/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.6617
# Epoch 65/400
# 31/31 [==============================] - 0s 4ms/step - loss: 40.5263
# Epoch 66/400
# 31/31 [==============================] - 0s 4ms/step - loss: 38.9033
# Epoch 67/400
# 31/31 [==============================] - 0s 4ms/step - loss: 38.0788
# Epoch 68/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.3190
# Epoch 69/400
# 31/31 [==============================] - 0s 3ms/step - loss: 37.3345
# Epoch 70/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.0891
# Epoch 71/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.6405
# Epoch 72/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.0415
# Epoch 73/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.3284
# Epoch 74/400
# 31/31 [==============================] - 0s 4ms/step - loss: 39.2971
# Epoch 75/400
# 31/31 [==============================] - 0s 4ms/step - loss: 38.1715
# Epoch 76/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.8636
# Epoch 77/400
# 31/31 [==============================] - 0s 4ms/step - loss: 38.3588
# Epoch 78/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.7520
# Epoch 79/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.5516
# Epoch 80/400
# 31/31 [==============================] - 0s 4ms/step - loss: 39.1302
# Epoch 81/400
# 31/31 [==============================] - 0s 3ms/step - loss: 37.2017
# Epoch 82/400
# 31/31 [==============================] - 0s 3ms/step - loss: 37.0008
# Epoch 83/400
# 31/31 [==============================] - 0s 4ms/step - loss: 38.6313
# Epoch 84/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.9411
# Epoch 85/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.0897
# Epoch 86/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.9883
# Epoch 87/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.5421
# Epoch 88/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.8144
# Epoch 89/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.9917
# Epoch 90/400
# 31/31 [==============================] - 0s 3ms/step - loss: 37.4804
# Epoch 91/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.7072
# Epoch 92/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.9851
# Epoch 93/400
# 31/31 [==============================] - 0s 2ms/step - loss: 37.5460
# Epoch 94/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.9379
# Epoch 95/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.5292
# Epoch 96/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.8626
# Epoch 97/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.1836
# Epoch 98/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.5383
# Epoch 99/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.3903
# Epoch 100/400
# 31/31 [==============================] - 0s 4ms/step - loss: 38.3392
# Epoch 101/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.7936
# Epoch 102/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.7442
# Epoch 103/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.2438
# Epoch 104/400
# 31/31 [==============================] - 0s 2ms/step - loss: 38.0503
# Epoch 105/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.1689
# Epoch 106/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.4131
# Epoch 107/400
# 31/31 [==============================] - 0s 4ms/step - loss: 38.0471
# Epoch 108/400
# 31/31 [==============================] - 0s 4ms/step - loss: 38.2463
# Epoch 109/400
# 31/31 [==============================] - 0s 3ms/step - loss: 37.1961
# Epoch 110/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.5911
# Epoch 111/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.0159
# Epoch 112/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.5977
# Epoch 113/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.6246
# Epoch 114/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.9972
# Epoch 115/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.5635
# Epoch 116/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.3861
# Epoch 117/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.7598
# Epoch 118/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.4555
# Epoch 119/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.5758
# Epoch 120/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.9703
# Epoch 121/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.0178
# Epoch 122/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.9437
# Epoch 123/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.3737
# Epoch 124/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.5021
# Epoch 125/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.3529
# Epoch 126/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.7952
# Epoch 127/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.2216
# Epoch 128/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.0765
# Epoch 129/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.5850
# Epoch 130/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.8452
# Epoch 131/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.8480
# Epoch 132/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.0773
# Epoch 133/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.1675
# Epoch 134/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.4600
# Epoch 135/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.9944
# Epoch 136/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.2991
# Epoch 137/400
# 31/31 [==============================] - 0s 4ms/step - loss: 38.0497
# Epoch 138/400
# 31/31 [==============================] - 0s 3ms/step - loss: 37.4874
# Epoch 139/400
# 31/31 [==============================] - 0s 2ms/step - loss: 36.3869
# Epoch 140/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.2278
# Epoch 141/400
# 31/31 [==============================] - 0s 3ms/step - loss: 37.7628
# Epoch 142/400
# 31/31 [==============================] - 0s 3ms/step - loss: 37.4558
# Epoch 143/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.4716
# Epoch 144/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.1484
# Epoch 145/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.8654
# Epoch 146/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.1679
# Epoch 147/400
# 31/31 [==============================] - 0s 4ms/step - loss: 38.0017
# Epoch 148/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.3767
# Epoch 149/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.6689
# Epoch 150/400
# 31/31 [==============================] - 0s 2ms/step - loss: 36.2932
# Epoch 151/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.0056
# Epoch 152/400
# 31/31 [==============================] - 0s 3ms/step - loss: 36.2015
# Epoch 153/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.4674
# Epoch 154/400
# 31/31 [==============================] - 0s 3ms/step - loss: 38.2402
# Epoch 155/400
# 31/31 [==============================] - 0s 4ms/step - loss: 38.6539
# Epoch 156/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.0243
# Epoch 157/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.7244
# Epoch 158/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.7994
# Epoch 159/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.8594
# Epoch 160/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.8627
# Epoch 161/400
# 31/31 [==============================] - 0s 4ms/step - loss: 38.2044
# Epoch 162/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.9787
# Epoch 163/400
# 31/31 [==============================] - 0s 3ms/step - loss: 36.0743
# Epoch 164/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.4848
# Epoch 165/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.7952
# Epoch 166/400
# 31/31 [==============================] - 0s 4ms/step - loss: 38.6241
# Epoch 167/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.4430
# Epoch 168/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.0864
# Epoch 169/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.7585
# Epoch 170/400
# 31/31 [==============================] - 0s 3ms/step - loss: 36.0683
# Epoch 171/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.4666
# Epoch 172/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.7699
# Epoch 173/400
# 31/31 [==============================] - 0s 3ms/step - loss: 36.0059
# Epoch 174/400
# 31/31 [==============================] - 0s 3ms/step - loss: 36.0945
# Epoch 175/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.9857
# Epoch 176/400
# 31/31 [==============================] - 0s 2ms/step - loss: 36.2492
# Epoch 177/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.8097
# Epoch 178/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.8571
# Epoch 179/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.4368
# Epoch 180/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.6757
# Epoch 181/400
# 31/31 [==============================] - 0s 3ms/step - loss: 35.6009
# Epoch 182/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.9401
# Epoch 183/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.3172
# Epoch 184/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.1794
# Epoch 185/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.3685
# Epoch 186/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.3456
# Epoch 187/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.1302
# Epoch 188/400
# 31/31 [==============================] - 0s 3ms/step - loss: 36.5440
# Epoch 189/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.0295
# Epoch 190/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.4773
# Epoch 191/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.9442
# Epoch 192/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.4153
# Epoch 193/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.7211
# Epoch 194/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.4354
# Epoch 195/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.4121
# Epoch 196/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.9078
# Epoch 197/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.2806
# Epoch 198/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.2450
# Epoch 199/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.5479
# Epoch 200/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.1861
# Epoch 201/400
# 31/31 [==============================] - 0s 2ms/step - loss: 35.2143
# Epoch 202/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.8019
# Epoch 203/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.0769
# Epoch 204/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.5720
# Epoch 205/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.5076
# Epoch 206/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.6462
# Epoch 207/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.6404
# Epoch 208/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.3515
# Epoch 209/400
# 31/31 [==============================] - 0s 3ms/step - loss: 36.1604
# Epoch 210/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.5421
# Epoch 211/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.3162
# Epoch 212/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.3970
# Epoch 213/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.4307
# Epoch 214/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.5392
# Epoch 215/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.1772
# Epoch 216/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.0284
# Epoch 217/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.0310
# Epoch 218/400
# 31/31 [==============================] - 0s 2ms/step - loss: 36.2468
# Epoch 219/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.3654
# Epoch 220/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.8402
# Epoch 221/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.3689
# Epoch 222/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.9452
# Epoch 223/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.1100
# Epoch 224/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.2514
# Epoch 225/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.7864
# Epoch 226/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.1171
# Epoch 227/400
# 31/31 [==============================] - 0s 3ms/step - loss: 35.9205
# Epoch 228/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.2981
# Epoch 229/400
# 31/31 [==============================] - 0s 3ms/step - loss: 35.3619
# Epoch 230/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.9656
# Epoch 231/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.9948
# Epoch 232/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.1820
# Epoch 233/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.2580
# Epoch 234/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.2480
# Epoch 235/400
# 31/31 [==============================] - 0s 3ms/step - loss: 35.6850
# Epoch 236/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.0947
# Epoch 237/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.7447
# Epoch 238/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.5085
# Epoch 239/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.4888
# Epoch 240/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.7033
# Epoch 241/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.5442
# Epoch 242/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.4748
# Epoch 243/400
# 31/31 [==============================] - 0s 3ms/step - loss: 36.0505
# Epoch 244/400
# 31/31 [==============================] - 0s 3ms/step - loss: 35.6152
# Epoch 245/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.9782
# Epoch 246/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.2716
# Epoch 247/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.5427
# Epoch 248/400
# 31/31 [==============================] - 0s 3ms/step - loss: 36.1851
# Epoch 249/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.9772
# Epoch 250/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.1874
# Epoch 251/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.2096
# Epoch 252/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.2010
# Epoch 253/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.3130
# Epoch 254/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.5898
# Epoch 255/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.6604
# Epoch 256/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.4737
# Epoch 257/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.0765
# Epoch 258/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.8669
# Epoch 259/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.6470
# Epoch 260/400
# 31/31 [==============================] - 0s 3ms/step - loss: 36.1535
# Epoch 261/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.1470
# Epoch 262/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.0691
# Epoch 263/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.1165
# Epoch 264/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.9808
# Epoch 265/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.6937
# Epoch 266/400
# 31/31 [==============================] - 0s 3ms/step - loss: 35.9046
# Epoch 267/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.5166
# Epoch 268/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.6924
# Epoch 269/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.2448
# Epoch 270/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.0019
# Epoch 271/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.3494
# Epoch 272/400
# 31/31 [==============================] - 0s 3ms/step - loss: 35.1829
# Epoch 273/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.3879
# Epoch 274/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.7373
# Epoch 275/400
# 31/31 [==============================] - 0s 3ms/step - loss: 35.6017
# Epoch 276/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.5351
# Epoch 277/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.5970
# Epoch 278/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.1842
# Epoch 279/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.9120
# Epoch 280/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.2051
# Epoch 281/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.8071
# Epoch 282/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.7847
# Epoch 283/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.4168
# Epoch 284/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.3497
# Epoch 285/400
# 31/31 [==============================] - 0s 3ms/step - loss: 37.1298
# Epoch 286/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.0708
# Epoch 287/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.2990
# Epoch 288/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.4099
# Epoch 289/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.8176
# Epoch 290/400
# 31/31 [==============================] - 0s 4ms/step - loss: 37.0797
# Epoch 291/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.1930
# Epoch 292/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.9337
# Epoch 293/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.9966
# Epoch 294/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.7435
# Epoch 295/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.0354
# Epoch 296/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.8197
# Epoch 297/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.6892
# Epoch 298/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.7266
# Epoch 299/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.3764
# Epoch 300/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.4064
# Epoch 301/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.9496
# Epoch 302/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.5647
# Epoch 303/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.0691
# Epoch 304/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.5298
# Epoch 305/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.0356
# Epoch 306/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.6561
# Epoch 307/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.3033
# Epoch 308/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.6184
# Epoch 309/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.8053
# Epoch 310/400
# 31/31 [==============================] - 0s 3ms/step - loss: 36.9012
# Epoch 311/400
# 31/31 [==============================] - 0s 4ms/step - loss: 39.3310
# Epoch 312/400
# 31/31 [==============================] - 0s 4ms/step - loss: 39.0964
# Epoch 313/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.4767
# Epoch 314/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.1722
# Epoch 315/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.2338
# Epoch 316/400
# 31/31 [==============================] - 0s 3ms/step - loss: 35.3810
# Epoch 317/400
# 31/31 [==============================] - 0s 3ms/step - loss: 34.7591
# Epoch 318/400
# 31/31 [==============================] - 0s 3ms/step - loss: 34.3922
# Epoch 319/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.3077
# Epoch 320/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.3751
# Epoch 321/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.7270
# Epoch 322/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.3416
# Epoch 323/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.1812
# Epoch 324/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.9536
# Epoch 325/400
# 31/31 [==============================] - 0s 3ms/step - loss: 36.6559
# Epoch 326/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.2823
# Epoch 327/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.2392
# Epoch 328/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.2597
# Epoch 329/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.5286
# Epoch 330/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.8454
# Epoch 331/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.4668
# Epoch 332/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.3577
# Epoch 333/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.5020
# Epoch 334/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.3776
# Epoch 335/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.8441
# Epoch 336/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.9624
# Epoch 337/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.6934
# Epoch 338/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.4648
# Epoch 339/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.5257
# Epoch 340/400
# 31/31 [==============================] - 0s 3ms/step - loss: 34.3956
# Epoch 341/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.1285
# Epoch 342/400
# 31/31 [==============================] - 0s 3ms/step - loss: 37.0480
# Epoch 343/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.7599
# Epoch 344/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.4808
# Epoch 345/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.0865
# Epoch 346/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.4336
# Epoch 347/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.6714
# Epoch 348/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.5479
# Epoch 349/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.9469
# Epoch 350/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.5085
# Epoch 351/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.6157
# Epoch 352/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.0656
# Epoch 353/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.3991
# Epoch 354/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.9515
# Epoch 355/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.5999
# Epoch 356/400
# 31/31 [==============================] - 0s 3ms/step - loss: 35.3187
# Epoch 357/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.1029
# Epoch 358/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.4839
# Epoch 359/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.7349
# Epoch 360/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.1041
# Epoch 361/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.1882
# Epoch 362/400
# 31/31 [==============================] - 0s 2ms/step - loss: 34.3209
# Epoch 363/400
# 31/31 [==============================] - 0s 3ms/step - loss: 36.5603
# Epoch 364/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.4034
# Epoch 365/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.8026
# Epoch 366/400
# 31/31 [==============================] - 0s 3ms/step - loss: 34.4443
# Epoch 367/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.3501
# Epoch 368/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.0274
# Epoch 369/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.8273
# Epoch 370/400
# 31/31 [==============================] - 0s 2ms/step - loss: 34.0373
# Epoch 371/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.0924
# Epoch 372/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.0273
# Epoch 373/400
# 31/31 [==============================] - 0s 3ms/step - loss: 34.6238
# Epoch 374/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.1231
# Epoch 375/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.3070
# Epoch 376/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.1017
# Epoch 377/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.2472
# Epoch 378/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.6762
# Epoch 379/400
# 31/31 [==============================] - 0s 3ms/step - loss: 34.9512
# Epoch 380/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.1641
# Epoch 381/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.6562
# Epoch 382/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.4441
# Epoch 383/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.3959
# Epoch 384/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.1642
# Epoch 385/400
# 31/31 [==============================] - 0s 3ms/step - loss: 35.5161
# Epoch 386/400
# 31/31 [==============================] - 0s 4ms/step - loss: 33.9268
# Epoch 387/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.0639
# Epoch 388/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.5818
# Epoch 389/400
# 31/31 [==============================] - 0s 4ms/step - loss: 35.2207
# Epoch 390/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.9326
# Epoch 391/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.1675
# Epoch 392/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.6850
# Epoch 393/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.6373
# Epoch 394/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.5587
# Epoch 395/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.6190
# Epoch 396/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.1498
# Epoch 397/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.4798
# Epoch 398/400
# 31/31 [==============================] - 0s 4ms/step - loss: 36.3218
# Epoch 399/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.4099
# Epoch 400/400
# 31/31 [==============================] - 0s 4ms/step - loss: 34.9607

# %% [markdown]
# You can plot the `loss` values by getting it from the [History](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/History) object returned by the `fit()` method. As you can see, the model is still trending downward after the training.

# %%
# Plot the loss
loss = history.history['loss']
epochs = range(len(loss))
plt.plot(epochs, loss, 'b', label='Training Loss')
plt.show()

# %%
# Plot all but the first 10
loss = history.history['loss']
epochs = range(10, len(loss))
plot_loss = loss[10:]
plt.plot(epochs, plot_loss, 'b', label='Training Loss')
plt.show()

# %% [markdown]
# You can get the preictions again and overlay it on the validation set.

# %%
# Initialize a list
forecast = []

# Reduce the original series
forecast_series = series[split_time - window_size:]

# Use the model to predict data points per window size
for time in range(len(forecast_series) - window_size):
  forecast.append(model_tune.predict(forecast_series[time:time + window_size][np.newaxis]))

# Convert to a numpy array and drop single dimensional axes
results = np.array(forecast).squeeze()

# Plot the results
plot_series(time_valid, (x_valid, results))

# %% [markdown]
# Finally, you can compute the metrics and you should arrive at similar figures compared to the baseline. If it is much worse, then the model might have overfitted and you can use techniques you know to avoid it (e.g. adding dropout).

# %%
print(tf.keras.metrics.mean_squared_error(x_valid, results).numpy())
print(tf.keras.metrics.mean_absolute_error(x_valid, results).numpy())
# Out:
# 40.317833
# 4.671122
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Wrap Up
#
# This concludes the exercise on using a deep neural network for forecasting. Along the way, you did some hyperparameter tuning, particularly on the learning rate. You will be using this technique as well in the next labs. Next week, you will be using recurrent neural networks to build your forecasting model. See you there and keep it up!
